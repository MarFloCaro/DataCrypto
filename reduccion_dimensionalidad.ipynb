# %% [markdown]
# # Reducción de dimensionalidad para índice de percepción/sentiment de la comunidad
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA
from endpoints import *

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * Listado de monedas

# %%
crypto_ids = ['bitcoin',
 'dash',
 'decred',
 'dero',
 'grin',
 'monero',
 'pirate-chain',
 'secret',
 'verge',
 'zcash',
 'zencash']

# %% [markdown]
# ## 1. Procesamiento de la columna categórica 'trust_score' del endpoint tickers
# ---

# %% [markdown]
# Llamamos al endpoint

# %%
tickers_dict = get_coins_tickers(crypto_ids)

# %% [markdown]
# Exploramos los posibles valores de la columna trusts scores

# %%
for key in tickers_dict:
    unique_trust_scores = tickers_dict[key]['trust_score'].unique()
    print(f"Puntajes únicos en el dataframe {key}: {unique_trust_scores}")
# Out:
# Puntajes únicos en el dataframe df_bitcoin_ticker: ['green']
# Puntajes únicos en el dataframe df_dash_ticker: ['green' 'yellow']
# Puntajes únicos en el dataframe df_decred_ticker: ['green' 'yellow' None 'red']
# Puntajes únicos en el dataframe df_dero_ticker: ['green' 'yellow' None]
# Puntajes únicos en el dataframe df_grin_ticker: ['green' 'red' None]
# Puntajes únicos en el dataframe df_monero_ticker: ['green' 'yellow' 'red' None]
# Puntajes únicos en el dataframe df_pirate_chain_ticker: ['green' None]
# Puntajes únicos en el dataframe df_secret_ticker: ['green' 'yellow' None 'red']
# Puntajes únicos en el dataframe df_verge_ticker: ['green' 'yellow' 'red' None]
# Puntajes únicos en el dataframe df_zcash_ticker: ['green' 'yellow' 'red' None]
# Puntajes únicos en el dataframe df_zencash_ticker: ['green' 'yellow' 'red' None]

# %% [markdown]
# Mapeamos a valores numéricos, y reemplazamos el valor categórico con el numérico

# %%
trust_score_mapping = {'green': 10, 'yellow': 5, 'red': 1}

for key in tickers_dict:
    tickers_dict[key]['trust_score'] = tickers_dict[key]['trust_score'].map(trust_score_mapping)

# %% [markdown]
# Guardamos en lista de dataframes, para posterior mapeo

# %%
tickers_df_list = list()

# %%
for key in tickers_dict:
    tickers_df_list.append((tickers_dict[key]))

# %%
tickers_df_list[0]
# Out:
#    base target        market_name market_identifier  \
# 0   BTC   USDT            Binance           binance
# 1   BTC   TUSD            Binance           binance
# 2   BTC    USD           Bitfinex          bitfinex
# 3   BTC    USD  Coinbase Exchange              gdax
# 4   BTC    USD             Kraken            kraken
# ..  ...    ...                ...               ...
# 95  ETH    BTC             BigONE            bigone
# 96  BTC    GBP  Coinbase Exchange              gdax
# 97  SOL    BTC             XT.COM                xt
# 98  BTC   USDT                Ace               ace
# 99  BTC   USDC             KuCoin            kucoin
#
#     market_has_trading_incentive          last        volume  \
# 0                          False  29215.990000  23011.613770
# 1                          False  29180.910000  54262.626950
# 2                          False  29160.000000    461.936111
# 3                          False  29138.780000   4971.568748
# 4                          False  29138.100000    953.414403
# ..                           ...           ...           ...
# 95                         False      0.062437   1363.127220
# 96                         False  22929.600000     71.789409
# 97                         False      0.000824  19763.600000
# 98                         False  29161.990000    119.753900
# 99                         False  29127.400000     67.592053
#
#     converted_last_btc  converted_last_eth  converted_last_usd  ...  \
# 0             0.997042           15.887636               29192  ...
# 1             1.002001           16.046863               29205  ...
# 2             1.000269           16.012976               29160  ...
# 3             0.999541           16.001324               29139  ...
# 4             0.999518           16.000950               29138  ...
# ..                 ...                 ...                 ...  ...
# 95            1.000000           16.009375               29113  ...
# 96            0.999213           15.996061               29129  ...
# 97            1.000000           16.014819               29147  ...
# 98            1.000138           16.011582               29117  ...
# 99            1.001373           16.031363               29153  ...
#
#     bid_ask_spread_percentage           timestamp      last_traded_at  \
# 0                    0.010034 2023-08-15 19:08:02 2023-08-15 19:08:02
# 1                    0.015834 2023-08-15 19:14:15 2023-08-15 19:14:15
# 2                    0.068540 2023-08-15 19:16:01 2023-08-15 19:16:01
# 3                    0.010034 2023-08-15 19:16:02 2023-08-15 19:16:02
# 4                    0.010343 2023-08-15 19:16:02 2023-08-15 19:16:02
# ..                        ...                 ...                 ...
# 95                   0.396362 2023-08-15 19:15:50 2023-08-15 19:15:50
# 96                   0.022384 2023-08-15 19:15:01 2023-08-15 19:15:01
# 97                   0.036417 2023-08-15 19:14:47 2023-08-15 19:14:47
# 98                   0.061924 2023-08-15 19:15:28 2023-08-15 19:15:28
# 99                   0.011668 2023-08-15 19:15:29 2023-08-15 19:15:29
#
#          last_fetch_at  is_anomaly is_stale  \
# 0  2023-08-15 19:09:00       False    False
# 1  2023-08-15 19:14:15       False    False
# 2  2023-08-15 19:16:01       False    False
# 3  2023-08-15 19:16:02       False    False
# 4  2023-08-15 19:16:02       False    False
# ..                 ...         ...      ...
# 95 2023-08-15 19:15:50       False    False
# 96 2023-08-15 19:16:01       False    False
# 97 2023-08-15 19:14:47       False    False
# 98 2023-08-15 19:15:28       False    False
# 99 2023-08-15 19:15:29       False    False
#
#                                             trade_url token_info_url  \
# 0   https://www.binance.com/en/trade/BTC_USDT?ref=...           None
# 1   https://www.binance.com/en/trade/BTC_TUSD?ref=...           None
# 2   https://trading.bitfinex.com/t/BTC:USD?type=ex...           None
# 3              https://pro.coinbase.com/trade/BTC-USD           None
# 4            https://pro.kraken.com/app/trade/BTC-USD           None
# ..                                                ...            ...
# 95                      https://big.one/trade/ETH-BTC           None
# 96             https://pro.coinbase.com/trade/BTC-GBP           None
# 97                   https://www.xt.com/trade/sol_btc           None
# 98                      https://ace.io/trade/BTC/USDT           None
# 99              https://www.kucoin.com/trade/BTC-USDC           None
#
#      coin_id  target_coin_id
# 0    bitcoin          tether
# 1    bitcoin        true-usd
# 2    bitcoin             NaN
# 3    bitcoin             NaN
# 4    bitcoin             NaN
# ..       ...             ...
# 95  ethereum         bitcoin
# 96   bitcoin             NaN
# 97    solana         bitcoin
# 98   bitcoin          tether
# 99   bitcoin        usd-coin
#
# [100 rows x 24 columns]

# %% [markdown]
# Aplanamos el dato de múltiples filas por moneda, a un solo valor por moneda, ponderando respecto a la cantidad de brokers

# %%
average_trust_scores = {}

for key, dataset in tickers_dict.items():
    # Usamos una base de promedio, y le agregamos un factor en aumento cuando aumentan el número de brokers
    avg_score = dataset['trust_score'].mean() * dataset.shape[0] * 1.5
    
    # Limpio las keys para usar los ids (y que sea más simple cruzar datos)
    if 'pirate_chain' not in key:
        clean_key = key.split('_')[1]
    else: 
        clean_key = 'pirate-chain'
    
    average_trust_scores[clean_key] = avg_score

average_trust_scores
# Out:
# {'bitcoin': 1500.0,
#  'dash': 1245.0000000000002,
#  'decred': 438.96774193548384,
#  'dero': 81.0,
#  'grin': 74.25,
#  'monero': 1126.3636363636363,
#  'pirate-chain': 165.0,
#  'secret': 454.6451612903226,
#  'verge': 421.3604651162791,
#  'zcash': 1262.0689655172414,
#  'zencash': 568.8666666666667}

# %% [markdown]
# ## 2. Procesamiento de las columnas numéricas del endpoint Coins
# ---

# %% [markdown]
# Llamamos al endpoint

# %%
df_coins, df_developers = get_coins_id_filtered(crypto_ids)

# %%
df_coins
# Out:
#               id symbol          name  block_time_in_minutes  \
# 0        bitcoin    btc       Bitcoin                     10
# 1           dash   dash          Dash                      2
# 2         decred    dcr        Decred                      5
# 3           dero   dero          Dero                      0
# 4           grin   grin          Grin                      1
# 5         monero    xmr        Monero                      2
# 6   pirate-chain   arrr  Pirate Chain                      1
# 7         secret   scrt        Secret                      0
# 8          verge    xvg         Verge                      0
# 9          zcash    zec         Zcash                      0
# 10       zencash    zen       Horizen                      2
#
#       hashing_algorithm                                         categories  \
# 0               SHA-256                     [Cryptocurrency, Layer 1 (L1)]
# 1                   X11  [Alleged SEC Securities, Cryptocurrency, Maste...
# 2             Blake-256        [Cryptocurrency, Governance, Privacy Coins]
# 3              AstroBWT           [Smart Contract Platform, Privacy Coins]
# 4   Multiple Algorithms                    [Cryptocurrency, Privacy Coins]
# 5               RandomX                                    [Privacy Coins]
# 6              Equihash               [Privacy Coins, Zero Knowledge (ZK)]
# 7                  None  [Smart Contract Platform, Privacy Coins, Cosmo...
# 8                Scrypt                                    [Privacy Coins]
# 9              Equihash               [Privacy Coins, Zero Knowledge (ZK)]
# 10             Equihash  [Masternodes, Privacy Coins, Zero Knowledge (ZK)]
#
#    genesis_date  sentiment_votes_up_percentage  \
# 0    2009-01-03                          74.72
# 1    2014-01-19                          55.56
# 2    2016-02-08                          66.67
# 3    2017-12-05                          75.00
# 4    2019-01-15                            NaN
# 5    2014-04-18                          93.33
# 6    2018-08-29                          63.64
# 7          None                          80.00
# 8    2014-10-09                          71.43
# 9    2016-10-28                          90.00
# 10         None                         100.00
#
#     sentiment_votes_down_percentage  watchlist_portfolio_users  \
# 0                             25.28                    1328408
# 1                             44.44                      82390
# 2                             33.33                      16458
# 3                             25.00                       9746
# 4                               NaN                       7964
# 5                              6.67                     114835
# 6                             36.36                      18369
# 7                             20.00                      58071
# 8                             28.57                      42568
# 9                             10.00                      68636
# 10                             0.00                      24173
#
#     market_cap_rank  coingecko_rank  coingecko_score  developer_score  \
# 0                 1               1           83.151           99.241
# 1               107              39           51.994           65.377
# 2               151              67           48.677           77.359
# 3               437             482           27.963           22.596
# 4              1178             226           35.921           72.995
# 5                26              12           61.097           87.299
# 6               430             217           36.358           51.505
# 7               299             120           43.613           82.601
# 8               356              64           49.214           79.653
# 9               145              18           56.684           87.898
# 10              234              73           48.097           66.476
#
#     community_score  liquidity_score  public_interest_score  \
# 0            83.341          100.011                  0.073
# 1            43.398           55.664                  0.010
# 2            37.138           31.911                  0.002
# 3            30.536           11.724                  0.003
# 4             6.546           21.440                  0.002
# 5            51.877           57.940                  0.034
# 6            33.960           11.999                  0.001
# 7            10.315           32.111                  0.002
# 8            43.240           32.093                  0.003
# 9            39.685           53.365                  0.004
# 10           37.234           45.073                  0.000
#
#               last_updated
# 0  2023-08-15 19:29:08.466
# 1  2023-08-15 19:29:12.574
# 2  2023-08-15 19:29:08.800
# 3  2023-08-15 19:28:50.756
# 4  2023-08-15 19:29:12.010
# 5  2023-08-15 19:29:10.159
# 6  2023-08-15 19:28:50.709
# 7  2023-08-15 19:29:11.003
# 8  2023-08-15 19:28:51.539
# 9  2023-08-15 19:29:13.753
# 10 2023-08-15 19:30:13.499

# %% [markdown]
# Inputamos el valor

# %%
df_coins.loc[df_coins['id'] == 'secret', 'hashing_algorithm'] = 'X11'

# %%
df_coins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               11 non-null     object
#  1   symbol                           11 non-null     object
#  2   name                             11 non-null     object
#  3   block_time_in_minutes            11 non-null     int64
#  4   hashing_algorithm                11 non-null     object
#  5   categories                       11 non-null     object
#  6   genesis_date                     9 non-null      object
#  7   sentiment_votes_up_percentage    10 non-null     float64
#  8   sentiment_votes_down_percentage  10 non-null     float64
#  9   watchlist_portfolio_users        11 non-null     int64
#  10  market_cap_rank                  11 non-null     int64
#  11  coingecko_rank                   11 non-null     int64
#  12  coingecko_score                  11 non-null     float64
#  13  developer_score                  11 non-null     float64
#  14  community_score                  11 non-null     float64
#  15  liquidity_score                  11 non-null     float64
#  16  public_interest_score            11 non-null     float64
#  17  last_updated                     11 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), int64(4), object(6)
# memory usage: 1.7+ KB

# %% [markdown]
# Creamos la nueva columna para reflejar la valoración de los brokers

# %%
df_coins['brokers_score'] = df_coins['id'].map(average_trust_scores)

# %% [markdown]
# Con la nueva columna, ahora vamos a trabajar en el índice unificado

# %%
df_coins
# Out:
#               id symbol          name  block_time_in_minutes  \
# 0        bitcoin    btc       Bitcoin                     10
# 1           dash   dash          Dash                      2
# 2         decred    dcr        Decred                      5
# 3           dero   dero          Dero                      0
# 4           grin   grin          Grin                      1
# 5         monero    xmr        Monero                      2
# 6   pirate-chain   arrr  Pirate Chain                      1
# 7         secret   scrt        Secret                      0
# 8          verge    xvg         Verge                      0
# 9          zcash    zec         Zcash                      0
# 10       zencash    zen       Horizen                      2
#
#       hashing_algorithm                                         categories  \
# 0               SHA-256                     [Cryptocurrency, Layer 1 (L1)]
# 1                   X11  [Alleged SEC Securities, Cryptocurrency, Maste...
# 2             Blake-256        [Cryptocurrency, Governance, Privacy Coins]
# 3              AstroBWT           [Smart Contract Platform, Privacy Coins]
# 4   Multiple Algorithms                    [Cryptocurrency, Privacy Coins]
# 5               RandomX                                    [Privacy Coins]
# 6              Equihash               [Privacy Coins, Zero Knowledge (ZK)]
# 7                   X11  [Smart Contract Platform, Privacy Coins, Cosmo...
# 8                Scrypt                                    [Privacy Coins]
# 9              Equihash               [Privacy Coins, Zero Knowledge (ZK)]
# 10             Equihash  [Masternodes, Privacy Coins, Zero Knowledge (ZK)]
#
#    genesis_date  sentiment_votes_up_percentage  \
# 0    2009-01-03                          74.72
# 1    2014-01-19                          55.56
# 2    2016-02-08                          66.67
# 3    2017-12-05                          75.00
# 4    2019-01-15                            NaN
# 5    2014-04-18                          93.33
# 6    2018-08-29                          63.64
# 7          None                          80.00
# 8    2014-10-09                          71.43
# 9    2016-10-28                          90.00
# 10         None                         100.00
#
#     sentiment_votes_down_percentage  watchlist_portfolio_users  \
# 0                             25.28                    1328408
# 1                             44.44                      82390
# 2                             33.33                      16458
# 3                             25.00                       9746
# 4                               NaN                       7964
# 5                              6.67                     114835
# 6                             36.36                      18369
# 7                             20.00                      58071
# 8                             28.57                      42568
# 9                             10.00                      68636
# 10                             0.00                      24173
#
#     market_cap_rank  coingecko_rank  coingecko_score  developer_score  \
# 0                 1               1           83.151           99.241
# 1               107              39           51.994           65.377
# 2               151              67           48.677           77.359
# 3               437             482           27.963           22.596
# 4              1178             226           35.921           72.995
# 5                26              12           61.097           87.299
# 6               430             217           36.358           51.505
# 7               299             120           43.613           82.601
# 8               356              64           49.214           79.653
# 9               145              18           56.684           87.898
# 10              234              73           48.097           66.476
#
#     community_score  liquidity_score  public_interest_score  \
# 0            83.341          100.011                  0.073
# 1            43.398           55.664                  0.010
# 2            37.138           31.911                  0.002
# 3            30.536           11.724                  0.003
# 4             6.546           21.440                  0.002
# 5            51.877           57.940                  0.034
# 6            33.960           11.999                  0.001
# 7            10.315           32.111                  0.002
# 8            43.240           32.093                  0.003
# 9            39.685           53.365                  0.004
# 10           37.234           45.073                  0.000
#
#               last_updated  brokers_score
# 0  2023-08-15 19:29:08.466    1500.000000
# 1  2023-08-15 19:29:12.574    1245.000000
# 2  2023-08-15 19:29:08.800     438.967742
# 3  2023-08-15 19:28:50.756      81.000000
# 4  2023-08-15 19:29:12.010      74.250000
# 5  2023-08-15 19:29:10.159    1126.363636
# 6  2023-08-15 19:28:50.709     165.000000
# 7  2023-08-15 19:29:11.003     454.645161
# 8  2023-08-15 19:28:51.539     421.360465
# 9  2023-08-15 19:29:13.753    1262.068966
# 10 2023-08-15 19:30:13.499     568.866667

# %%
coins_corr = df_coins.corr()

plt.figure(figsize=(12, 8))

sns.heatmap(coins_corr, annot=True, cmap='coolwarm', center=0)

plt.title('Matriz de Correlación con Mapa de Calor')
plt.show()

# %% [markdown]
# Hay columnas que son prácticamente equivalentes, como sentiments_votes_up vs sentiments_vote_down, liquidity_score vs coingecko_score (lo que sugiere que el score de coingecko está fuertemente influenciado por la liquidez); y también public_interest_score vs watchlist_porfolio_users (lo que sugiere que el score se basa fuertemente en la cantidad de usuarios que tienen la moneda en su watchlist).

# %% [markdown]
# Por este motivo, vamos a seleccionar cuidadosamente las columnas

# %%
exclude_columns = ['id', 'symbol', 'name', 'block_time_in_minutes', 'hashing_algorithm', 'categories', 'genesis_date',
                   'last_updated', 'sentiment_votes_down_percentage', 'watchlist_portfolio_users', 'liquidity_score'
                ]

features = df_coins[df_coins.columns.difference(exclude_columns)]

features
# Out:
#     brokers_score  coingecko_rank  coingecko_score  community_score  \
# 0     1500.000000               1           83.151           83.341
# 1     1245.000000              39           51.994           43.398
# 2      438.967742              67           48.677           37.138
# 3       81.000000             482           27.963           30.536
# 4       74.250000             226           35.921            6.546
# 5     1126.363636              12           61.097           51.877
# 6      165.000000             217           36.358           33.960
# 7      454.645161             120           43.613           10.315
# 8      421.360465              64           49.214           43.240
# 9     1262.068966              18           56.684           39.685
# 10     568.866667              73           48.097           37.234
#
#     developer_score  market_cap_rank  public_interest_score  \
# 0            99.241                1                  0.073
# 1            65.377              107                  0.010
# 2            77.359              151                  0.002
# 3            22.596              437                  0.003
# 4            72.995             1178                  0.002
# 5            87.299               26                  0.034
# 6            51.505              430                  0.001
# 7            82.601              299                  0.002
# 8            79.653              356                  0.003
# 9            87.898              145                  0.004
# 10           66.476              234                  0.000
#
#     sentiment_votes_up_percentage
# 0                           74.72
# 1                           55.56
# 2                           66.67
# 3                           75.00
# 4                             NaN
# 5                           93.33
# 6                           63.64
# 7                           80.00
# 8                           71.43
# 9                           90.00
# 10                         100.00

# %% [markdown]
# Ahora aplicamos pre procesamiento y reducción de la dimensionalidad para lograr un índice único

# %%
# Manejar valores faltantes
imputer = SimpleImputer(strategy='mean')  # You can choose 'mean', 'median', etc.
features_imputed = imputer.fit_transform(features)

# Estandarizamos las features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features_imputed)

# Reducimos dimenasionalidad
pca = PCA(n_components=3)
reduced_features = pca.fit_transform(scaled_features)

# Calculamos el unified indicator usando los componentes PCA
df_coins['unified_indicator'] = reduced_features.mean(axis=1)

# %% [markdown]
# Exportamos a csv

# %%
df_coins.to_csv("df_coins.csv", index=False)
